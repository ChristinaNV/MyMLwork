# %%
Mesh={   
    "Characters":{'blade-master','Heartbreaker', 'Pugna', 'Saber Cleaver', 'Axe', 'Set', 'Xayah', 'Chen', 'Chronos', 'Yu Huang', 'Quinn', 'Phantom Fighter', 'Militia', 'Master Frost Bowman', 'Pantheon', 'Shaco', 'Poppy', 'Morgana', 
            'Galio', 'Senna', 'Talon', 'Baba Yaga', 'Mulan', 'Zeri', 'Kassadin', 'Ezreal', 'Griffin', 'Melee Units', 'Berserker (Proud)', 'Michael', 'Gragas ', 'Renegade Sail Ripper', 'Pain-Da', 'Spectre', 'Ashe',
            'Nike', 'Fafnir', "Chang'e", 'Hades', 'Valkyrie', 'Bristleback', 'Spirit Mage', 'Disruptor', 'Renata Glasc', 'Oracle', 'Engineer', "Kog'Maw", 'Serqet', 'Exorcist', 'Crystal Ooze', 'Trundle', 'Awilix',
            'Rubick', 'Professor Ribbit', 'Phoenix', 'Zoe', 'Terrorblade', 'Gyrocopter', 'Renegade Norseman Bowman', 'Hunter', 'Crystal Maiden', 'Bone Huntress', 'Twisted Fate', 'Snapfire', 'Nocturne', 'Elder Titan', 
            'Super Valkyrie', 'Chernobog', 'Renegade Cultist Warrior', 'Io', 'Ravana', 'Cassiopeia', 'Scylla', 'Chaos Knight', 'Veteran Slingshot', 'Jakiro', 'Ah Muzen Cab', 'Sylas', 'Ninja', 'Bloodseeker', 'Loki',
            'Anti-Mage', 'Immortep', 'Super Giant', 'Rengar', 'Bowler', 'Veteran Swordsman', 'Yemoja', 'Assassin', 'Veteran two-handed swordsman', 'Necrophos', 'Camille', 'Windranger', 'Malphite', 'Tidehunter',
            'Royal Crossbowman', 'Hachiman', 'Xerath ', 'Veteran Pyromaniac', 'Atlas', 'Demogorgon', 'Shadow Crossbowman', 'Inferno Dragon', 'Slingshot', 'Raijin', 'Hoodwink', 'Skarner', 'He Bo', 'Skeletica', 
            'Templar Assassin', 'Lissandra', 'Aphelios', 'Abaddon', 'Naga Siren', 'Shadow Demon', 'Cupid', 'Forest WarriorForest Hunter', 'Assassin', 'Tahm Kench', 'Shadow Wretch', 'Alistar', 'Gnomad warrior',
            'Pumpkin Duke', 'Da Ji', 'Shadow Rogue', 'Golem', 'Executioner', 'Barbarian', 'Ra', 'Orianna', 'Shield-maiden', 'Tryndamere', 'Rell ', 'Lucian', 'Sasquatch', 'Brewmaster', 'Undying', 'Nidalee', 'Illaoi', 
            'Relic Axeman', 'Gnomad archer', 'Ah Puch', 'Drow Ranger', 'Thresh', 'Tiamat', 'Shyvana', 'Orksbane', 'Halberdier', 'Forest Guardian', 'Renegade Saber Warrior', 'Athena', 'Moltanica', 'Recruitment, Researching, Healing',
            'Archer Queen', 'Veteran Marauder', 'Ice Golem', 'Espirita', "Kha'Zix", 'Kuzenbo', 'Vulcan', 'Veteran Maceman', 'Clinkz', 'Kunkka', 'Super Wizard', 'Zhong Kui', 'Faceless Void', 'Sivir', 'Treant', "Rek'Sai",
            'Lion', 'Olorun', 'Dr. Mundo', 'Cirrina', 'Troll Warlord', 'Lifestealer', 'Renegade Cave Hunter', 'Puck', 'Aries', 'Cabrakan', 'Rama', 'Winter Wyvern', 'Succubus', 'Bounty Hunter', 'Atlanticore', 'Morphling',
            'Ullr', 'Treantaur', 'Anivia', 'Ao Kuang', 'Wraith King', 'Sobek', 'Death Knight', 'Artemis', 'Elite Crossbowman (Steel-hearted)', 'Cerberus', 'Amumu', 'Syndra', 'Veteran Composite Bowman', 'Morgan Le Fay',
            'Kled', 'Gangplank ', 'Amaterasu', 'Samira', 'Renegade Desert Bowman', 'Rakan', 'Bacchus', "Nature's Prophet", 'Dracax', 'Vladimir', 'Camazotz', 'Ivern', 'Venomancer', 'Kindred', 'Super Bowler', 'Goblin', 
            'Ember Spirit', 'Lycan', 'Izanami', 'Marksman', 'Draven', 'Baron Samedi', 'Nu Wa', 'Legion Commander', 'Sona', 'Composite Bowman', 'Viego', 'Warwick', 'Vi ', 'Vamana', 'Xbalanque', 'Sion', 'Asura', 'Fenrir',
            'Cosmo', 'Dragon Knight', 'Omniknight', 'Yuumi', 'Shen', 'Dread Drake', 'Katarina', 'Beastmaster', 'Wall Breaker', 'Bellona', 'Veteran Halberdier', 'Beast Tamer', 'Renegade Cultist Bowman', 'Mirana', 'Anubis', 
            'Kennen', 'Great Sage', 'Rumble', 'Aatrox', 'Sylvanus', 'Renegade sai warrior', 'Yorick', 'Charybdis', 'Super Archer', 'Erlang Shen', 'Monkey King', 'Azir', 'Zeus', 'Wizard', 'Earthshaker', 'Irelia ', 'Hercules', 
            'Pele', 'Neeko', 'Thoth', 'Ancient Apparition', 'Lee Sin', 'Bastet', 'Tinker', 'Crossbowman', 'Renegade Norseman Warrior', 'Persephone', 'Cernunnos', 'Plant Warrior', 'Baby Dragon', 'Ghoulem', 'Riki', 'Earth Spirit', 
            'Ice Demon', 'Luna', 'Werewolf', 'Kali', 'Huskar', "Vel'Koz ", 'Wukong', 'Void Spirit', 'Renegade Shark Tooth Warrior', 'Lava Hound', 'Janna', 'Morrigant', 'Skull Knight', 'Lulu', 'Renegade Spear Thrower', 'Druid', 
            'Bogeyman', 'Ursa', 'Veteran Bowman', 'Witch Doctor', 'Lux', 'Treant Protector', 'Fairy Dragon', 'Ymir', 'Super Wall Breaker', 'Pudge', 'Renegade Katana Warrior', 'Imperial Marksman (Deathclaw)', 'Ne Zha', 'Bakasura',
            'Ganesha', 'Brand', 'Pangolier', 'Ornn', 'Artio', 'Renegade Bow Master', 'Freya', 'Fiddlesticks', 'Triton', 'Longbowman', 'Tusk', 'Queen Pain', 'Pyke', 'Angel', 'Nautilus', 'Visage', 'Forest Bowmant', 'Pyromancer', 'Ranged Units',
            'Maceman', 'Dawnbreaker', 'Jinx ', 'Demon Shadow', 'Harpy Queen', 'Veteran Heavy Crossbowman', 'Pyromaniact', 'Storm Spirit', 'Vlad Dracula', 'Udyr', 'Urgot', 'Raven Chomper', 'Renegade Lancer', 'Witch', 'Bane', 'Spear Woman (Remorseless)', 
            'Discordia', 'Odin', 'Paladin', 'Geb', 'Achilles', 'Rockno', 'Silencer', 'Viper', 'Hill Giant', 'Rocket Balloon', 'Lady Leo', 'Death Prophet', 'Viktor', 'Anhur', 'Taliyah', 'Grand Warden', 'Miner', 'Vayne', 'Mars', 'Super Dragon', 'Siren', 
            'Hammer Dwarf', 'Ratatoskr', 'Mechtessa', 'Outworld Destroyer', 'Night Stalker', 'Varus', 'Fire Witch', 'Neith', 'Xing Tian', 'Graves', 'Elise', 'Fiora', 'Hera', 'Maokai', 'Qiyana', 'Weaver', 'Kumbhakarna', 'Slardar', 'Veigar', 'Shadow Felon', 'Super Witch', 
            'Skeletal hunter', 'Grimfiend', 'Twitch', 'Slime', 'Vex', 'Master Archer', 'Heimdallr', 'Malzahar', 'Santa Boom', 'Danzaburou', 'Tsukuyomi', 'Relic Longbowman', 'Kungfu Master', 'Susano', 'Lazulix', 'Centaur', 'Commodora', 'Eset', 'Cyclops', 'Thunder God',
            'Shadow Maceman', 'Balloon', 'Nunu & Willump', 'Zac', 'Pixie', 'Marauder', 'Slark', 'Agni', 'Ice Hound', 'Terra', 'King Arthur', 'Lich', 'Nox', 'Barbarian King', 'Pumpkin Butcher', 'Singed', 'Horus', 'Bear Bowman', 'Khepri', 'Diana', 'Imperial Guardsman (Stormpike)',
            'Cow Berdier', 'Shaman', 'Two-handed Swordsman', 'Yeti', 'Seraphine', 'Yasuo ', 'Swordsman', 'Veteran Longbowman', 'Shadow Shaman', 'Sun Wukong', 'Fizz ', 'Dragon', 'Veteran Saber Cleaver', 'Dove Keeper', 'Kayle', 'Wolfhound', 'Nemesis', 'Renegade Stone Smasher', 'Bear Warrior',
            'Hel', 'Serpent Queen', 'Elite Knight (Victorious)', 'Phantom Lancer', 'Ornithopter', 'Akshan', 'Grizzly Reaper', 'Zilean', 'Gwen', 'Dryad', 'Protector north', 'Hecarim ', 'Leona', 'Lion Warrior', 'Chaac', 'Jing Wei', 'Timbersaw', 'Relic Hammerman', 'Arc Warden', 'Clockwerk', 'Swain',
            'Candy Kane', 'Chiron', 'Zed', 'Karthus', 'Sejuani', 'Teemo ', 'Sol', 'Ronin', 'Headhunter', 'Kalista', 'Riven', 'Archer', 'Shotgun Dwarf', 'Keeper Light', 'Blitzcrank', 'Mercury', 'Athene', 'Revenant', 'Ares', 'Dragon Rider', 'Sven', 'Volibear', 'Akali', 'Ryze', 'Gunslinger',
            'Veteran Spearman', 'Master Bone Huntress', 'Armed Citizen', 'Longbow Ox', 'Renekton', 'Darius', 'Poseidon', 'Corki', 'Medusa', 'Storm Eater', 'Jayce', 'Valkyrie ranger', 'Veteran Flame Bearer', 'Xin Zhao', 'Skeleton Bowman', 'Royal Scout', 'Dark Seer', 'Kukulkan', 'Ripper',
            'Nasus', 'Veteran demon horror', 'Marci', 'Super Minion', 'Wallawalla', 'Frost Witch', 'Jhin', 'Jarvan IV', 'Veteran Crossbowman', 'Mordekaiser', 'Thor', 'Electro Dragon', 'Master Slime', 'Deathly Horror', 'Zyra', 'Flame Bearer', 'Soraka', 'Lavanica', 'Merlin', 'Ahri', 'Hog Rider', 
            'Travelling Knight', 'Apollo', 'Imperial Bowman (the Fearbringer)', 'Heavy Crossbowman', 'Renegade Kunai Thower', 'Caitlyn', 'Travelling Crossbowman', 'Ziggs', "Kai'Sa", 'Royal Sentinel', 'Lone Druid', 'Sneaky Goblin', 'Ogre Magi', 'Destroyer', 'Cu Chulainn', 'Warlock', 'Hou Yi',
            'P.E.K.K.A', 'Shiva', 'Gilgamesht', 'Phantom Assassin', 'Skadi', 'Doom', 'Valentina', 'Veteran deathly horror', 'Osiris', 'Creation-01', 'Magnus', 'Trixie Treat', 'Champion', 'Braum ', 'LeBlanc', 'Centaur Warrunner', 'Valkyrie sniper', 'Relic Shortbowman', 'Jax', 'Cthulhu', 'Minion', 
            'Tyr', 'Evelynn', 'Guardian', 'Savage Ogre', 'Shadow Fiend', 'Techies', 'Gelatinous Champion', 'Karma', 'Royal Knight', 'Arctica', 'Mecha Man', 'Leshrac', 'Sniper', 'Tristana', 'Gnar', 'Underlord', 'Snowzilla', 'Meepo', 'Ekko', 'Nyx Assassin', "Lil' Nick", 'Super Barbarian', 'Rosaleen', 'Imperial Knight (Oppressor)', 
            'Rammus', 'Nami', 'Tiny', 'Frost Bowman', 'Sand King', 'Annie', 'Renegade Swashbuckler', 'Thanatos', 'Master Swordsman', 'Enchantress', 'Rowdy Rascals', 'Khan Guards', 'Phantom King', 'Enigma', 'Muscle Man', 'Royal Champion', 'Lina', 'Lion Bowman', 'Cliodhna', 'Dark Willow', 'Broodmother', 'Ma Hatma', 'Sett', 
            'Spirit Breaker', 'Healer', 'Demon Slayer', 'Heimerdinger', 'Jormungandr', 'Razor', 'Batrider', 'Miss Fortune', 'Bowman', 'Juggernaut', 'Aurelion Sol ', 'Vengeful Spirit', 'Taric', 'Lillia ', 'Demon Horror', 'Dazzle', 'Spearman', 'Grimstroke', 'Yone', 'Renegade Cave Smasher', 'Arachne', 'Hun Batz', 'Giant', 'Minotaur Chieftain', 'Garen ', 
            'Aphrodite', 'Skywrath Mage', 'Janus', 'Master Yi ', "Cho'Gath", 'Shadow Scoundrel', 'Kayn', 'Bard', 'Alchemist', 'Battle Machine', 'Invoker', 'Guan Yu', 'Deathly Shadow', 'Primal Beast', 'Olaf'},
   "Customization":{"male","female","Primary","Secondary","Detail","Emissive","Skin Tone"},
   "Classes":{"Summoner","Blade Dancer","Gunslinger","Astromancer ","Kung Fu Master","Destroyer","Soul Fighter",
               "Blade Master","Assassin", "Warlock","Warden","Dual Blades","Force Master","Zen Archer",
               "Death Knight","Demon Hunter","Druid","Hunter","Mage","Monk","Paladin","Priest","Rogue","Shaman", "Warrior","Evoker"},    
   "Races":{"Lyn","Gon","Jin","Yun","Draenei","Dwarf","Gnome","Human","Night elf","Pandaren","Worgen","Blood elf","Forsaken","Goblin",
            "Orc","Pandaren","Tauren","Troll","Dracthyr","Undead","Dark Iron dwarf","Highmountain tauren","Kul Tiran","Lightforged draenei",
            "Mag'har orc","Nightborne","Void elf","Vulpera","Zandalari troll"},  
   "Faction":{"Bamboo Guard","Blackram","Stratus Empire","Tyrian Cultist","Skyhaven Resistance","Talus Dominion","Cerulean Order","Crimson Legion","Cerulean Officer","Crimson Officer",
              "Cerulean Elite","Crimson Elite","Cerulean Elite Initiate","Crimson Elite Initiate","Alliance","Horde"},
   "Equipment_Tool":{'Burning Flames', 'Attacker', 'Ashes in the Fall', 'Blight Stone', 'Twin Lords Block Soul Shield', 'Golden royal token chest', 'Hongmoon Duster', 'No Worries', 'Temptress', 'Defender ', 
                'Wild Horse', 'Bloodcrow treasures', 'Siege Barracks', 'Tyrian Remnant Accuracy Soul Shield', "Samja's Block Soul Shield", "Ogong's Evasion Soul Shield", 'Scorpio Soul Shield', 'Red Specter',
                'Sacrifice Soul Shield', 'War horn', 'Infinite Challenge', 'Dark Sandstorm', 'High Dragon Raiment', 'Heavy ballast stone', 'Beast Hunter', "Hulking Augerite's Combat Soul Shield", 'Balrok Defense Soul Shield',
                'Eternal Shroud ', "Soldier's banner", 'Stone Slammer', 'Gems', 'Ballast stone', 'Royal coin case', 'Commander Equipment', 'Marauder Accuracy Soul Shield', 'Lotus Critical Soul Shield', 'Demon Scepter',
                'Hoglin Blocking Soul Shield', 'Pirate Captain', 'Seductress', 'Fervent', 'Lotus Orb', 'Battle Blimp', 'Commanders', 'Roc Accuracy Soul Shield', 'Veteran banner', 'Quelling Blade', 'Bamboo ladder', 'Vanguard',
                'Dusk Adder Block Soul Shield', 'Kaari Suit', 'Jaofang Block Soul Shield', 'First Step', 'Shock Ploggle Evasion Soul Shield', 'Jetpack', 'Artifacts  Ivory Queen', 'Helm Iron Will', 'Tyrian Evasion Soul Shield',
                'Lycandi Evasion Soul Shield', 'Orb Venom', 'Ghost in the Shell', 'Elite Critical Soul Shield', 'Creeping Danger Accuracy Soul Shield', 'Lamentation', 'Entrenched', 'Taint Soul Shield', 'Nanocrafter', 'Map',
                'Silverfrost Valor Soul Shield', 'Dokkaebi Accuracy Soul Shield', 'Flame Flinger', 'Miser', 'Moonwater Courage Soul Shield', 'Sealed Palace Raiment', 'Dokkaebi Evasion Soul Shield', 'Stone Monster Block Soul Shield',
                'Golden Deva Soul Shield', 'Shaman Combat Soul Shield', 'Mineshaft Defense Soul Shield', 'Boulders', 'Royal Banner', 'Poison Arrows', 'Log Launcher', 'Manta Style', "Scorpion King's Combat Soul Shield",
                'Black King Bar', 'Pale Wanderer', 'Python Soul Shield', 'Stone Sentinel Block Soul Shield', 'Blitz Knuckles', 'Ebondrake Soul Shield', 'King Block Soul Shield', 'Conqueror', 'Cast iron mantlet', 'Crimson Guard', 
                'Enchanting Seductress', 'Wu Fee Combat Soul Shield', 'Gloomdross Evasion Soul Shield', 'Yeti Soul Shield', 'Loot cart', 'Lycan Soul Shield', 'Claypaw Defense Soul Shield', 'Ivory Specter', 'Dokkaebi Block Soul Shield',
                'Twist of Fate', 'Deva Raiment', 'Asura Soul Shield', 'Bandit Queen', 'Treasure Hunter', 'Sentinel Combat Soul Shield', 'Acquired Taste', 'Concealed', "Dura's Critical Soul Shield", 'Dark Pirate King', 'Onslaught bridge',
                'Hoglin Bandit Block Soul Shield', 'Hermit', 'Bloodshade Soul Shield', 'Maraude', 'Chuluun the Strong Accuracy Soul Shield', 'Earthseer', 'Stinger', 'Dark Wanderer', 'Banner Demon Slayers', 'Blackram Critical Soul Shield', 
                'Dahlia Critical Soul Shield', 'Arrow rain ballista', 'Hero', 'Ancestral Soul Shield', 'Blades Attack ', 'White Moon', 'Assault bridge', 'Frosty Evasion Soul Shield', 'Stalker Soul Shield', 'Bell Spring', 'Pugilist', 
                'Automaton Defense Soul Shield', "Champion's Accuracy Soul Shield", 'Pale Stalker Raiment', 'Horsetail standard', 'Dark Flames', 'Virtual Scafolding Projector', 'Talus Block Soul Shield', 'Blackram Accuracy Soul Shield', 
                'Forgotten Brightstone Soul Shield', 'Masked Hongmoon', 'Red Mask', 'Talus Accuracy Soul Shield', 'Chainmail', 'Elite Block Soul Shield', 'Mantlet', 'Pure Evil', 'Jiangshi Raiment', 'Mindless Strawman Block Soul Shield', 
                'Castellans', 'Augerite Block Soul Shield', 'Talus Dungeon Health Soul Shield', "Imperator's Defense Soul Shield", 'Gnarlox Defense Soul Shield', 'Vulture Accuracy Soul Shield', 'DSAT', 'Territory Scanner', 'Ruins Defense Soul Shield',
                'Profane Soul Shield', 'Red Pirate Princess', 'Moonwater Arena Soul Shield', 'Undead Accuracy Soul Shield', 'Hurricane Pike', 'Loot sack', 'Claymore', 'Market Tools', 'Bodyguard', 'Siege tower', 'Aeon Disk ', 'Traitor', 'Scanner Tool',
                'Iron ram', "Fiend's Evasion Soul Shield", 'Yutay Evasion Soul Shield', 'Unbroken', 'Black Ice', 'Pondskip Accuracy Soul Shield', 'Brigand Soul Shield', 'Soul Booster ', 'Silver Cauldron', 'Scout', 'Dreadtide Critical Soul Shield',
                'Shield wall', 'Labyrinth Soul Shield', 'Infused Raindrops', 'Mithril Hammer', 'Fiend Soul Shield', 'Dokumo Critical Soul Shield', 'Balrok Raiment', 'Talus Commander Accuracy Soul Shield', 'Golden royal coin case', 'Soul Warden', 
                'Deceitful', 'Javelin', 'Gust Evasion Soul Shield', 'Moonlight Soul Shield', 'Spirit Realm Accuracy Soul Shield', 'Noble of the Sea', 'Gloves Haste', 'Militia Training Soul Shield', 'Blackram General', 'Raptor Combat Soul Shield',
                'Bonemask Defense Soul Shield', 'Wolfskin', 'Kaari Soul Shield', 'Bloodstone', 'Thunder God', 'Viridian Valor Soul Shield', 'Steadfast', 'Profane Shroud', 'Jackal Accuracy Soul Shield', 'Assault Cuirass', 'Snapjaw Accuracy Soul Shield', 
                'Blackram Supply Soul Shield', 'Stratus Empire Critical Soul Shield', 'Case Samurai Tokens', 'Iron Rain', 'Naksun Soul Shield', 'Enchanting Temptress', 'Combatant', 'Xanos Soul Shield', 'Wolverine ram', 'Simyu Defense Soul Shield',
                'Merry Potter', 'Be Ido Soul Shield', 'Nanoformer', 'Desert Terror Defense Soul Shield', "Moonwater Renowned Valor's Soul Shield", 'Grimhorn Defense Soul Shield', 'Endless Tower Soul Shield', 'Crystal ballista', 'Red Viper Critical Soul Shield',
                'Elite spiked shield', 'Lumang Accuracy Soul Shield', 'Ring of Protection ', 'Ethereal Phantom', 'Codex', 'Starling', 'Shadowmist Evasion Soul Shield', 'Talent Interface', 'Mercenary Critical Soul Shield', "Bootlegger's Critical Soul Shield", 
                'Challenge Soul Shield', 'Bokgon Block Soul Shield', 'Elite Evasion Soul Shield', 'Unstoppable', 'Wood bundle', 'Premium royal token chest', 'Obsidian Serpent', "Hero's banner", 'Organization', 'Pirate Princess', "King's Banner", 
                'Plog Soul Shield', 'Just', 'Koki Evasion Soul Shield', "Cinderlands Renowned Valor's Soul Shield", 'Battering ram', "Treasure Hunter's Evasion Soul Shield", 'Fleet shield', 'Sacred Beast Critical Soul Shield', 'Scorpion Soul Shield',
                'Banner Triumph', 'Skyhaven Evasion Soul Shield', 'Heavy ram', 'Sparring Soul Shield', 'Besieger', 'Wall Wrecker', 'Black Sun', 'Premium royal coin case', 'Destroyer', 'Tarn Thrasher Defense Soul Shield', 'Heart Tarrasque', 'Elite tonnelon', 
                'Sovereign Tools', 'Twisted Soul Shield', 'Firefighter', 'Oblivion Soul Shield', 'Blackram Officer', 'Chest Samurai Tokens', 'Wind God', 'Trebuchet', 'Old Stratus Empire Armor', 'Broadsword', "Predator's Critical Soul Shield", 'Radiant Ring',
                'Forgekeeper', 'Nanopack', 'E. Fleet Evasion Soul Shield', 'Breaching tower', 'Exploration Tools', 'Invader', 'Necropolis Denizen Block Soul Shield', 'Rights, Duties Management System', "Cinderlands Unsung Hero's Soul Shield", 'Hongmoon Uniform',
                'Breaker', 'War banner', "Linken's Sphere", 'Banner', 'Quarterstaff', 'Mushin Soul Shield', 'Hood Defiance', "Shiva's Guard ", 'Bowman', 'Royal token chest', 'Building Tools', 'Blight Soul Shield', 'Yes Men Evasion Soul Shield', 'Pirate King',
                'Primal Accuracy Soul Shield', "Equipment's suffix", 'Shellraiser Critical Soul Shield', 'Scaling ladder', 'Blade Mail', 'Shield Wall','Moonlight','Red Dwarf','Iron Will','Star Candy','Ascending Cloud','Dark Scholar','Fragrance of Life','Highborn',
                'Grave Raider','Azure Wind','Azure Mist','Azure Smoke','Gourd Bottle','Officer Uniform','Allegiance','Best Friend','Black Padded Coat','Blue Porcelain','Chime','Chronicle','Class Act','Cobalt Captain','Colorful Autumn',
                'Dahlia','Dark Angel',"Demon Maw","Devotion","Dreamcutter","Empress Regalia","Fight Fire with Fire","Grand Cloud","Heavenly",
                "Holly Jolly","Ivory Bat","Ivory Bird","Light Specter","Merry Weather","Midnight Detective","Millenium","My Angel","Noblesse","Prime Time","Pure White","Rising Sun","Scarlet Bird","Scarlet Shade","Back to School","Secret Agent","Showgirl","Silver Dragon","Snowy Night","Soulmate","Spring Breeze","Strange Allure","Summer Beach","Summer Nights","Traveler","Voyager","White Dragon","White Hot","White Night","White Rosetta","White Sandraider","Wild Stallion","Windertide","Winter Flower","Wish","Yellow Dahlia","Butterfly","Luciole","Red Queen","Breezy","Adventurer","Baby Blue Bear","Pinky Bear","Triumph","Crimson Tide","Great General","Business Casual","Dive Team","Shadow Guard","Strictly Business","Summer Groove","Summer Waves","Finite Challenge","Lotus"
                },
   "Pets":{"L.A.S.S.I","Electro Owl","Mighty Yak","Unicorn","Auroria","Aviar","Bubblow","Celestin","Chickaboom","Doom Balloon","Drako","Finix","Little Havoc","Mini Angi","Purrsalot","Yulephant","Ruduff","Piblob"},
   "Spells":{'Lightning Spell', 'Healing Spell', 'Rage Spell', 'Jump Spell', 'Freeze Spell', 'Clone Spell', 'Invisibility Spell','Poison Spell', 'Earthquake Spell', 'Haste Spell', 'Skeleton Spell', 'Bat Spell',
        'Arrow Rain', 'Restoration', "Ares' Fervor", 'Windstorm', 'Guardian Angel', 'Meteor', 'Disaster', "Ares' Frenzy", 'Phoenix Flight', 'Snowstorm',"Druid Spells","Mage Spells","Paladin Spells","Priest Spells","Shaman Spells","Warlock Spells",
        "Arcane spells","Fire spells","Nature spells","Frost spells","Shadow spells","Holy spells",'Spell Prism','Spell Focus'},
  "Buildings":{'Arrow Tower', 'Stables', 'Heroes Altar', 'Armory', 'Tavern', 'Dark Spell Factory', 'X-Bow', 'Horsetail Banner', 'Capitals', 'Clan Castle(Treasury)', 'Flags', 'Flower', 'Decorations',
           'Barbarian King Altar', 'Cannon Tower', 'Relic Bakery', ' Snowman', 'Dark Barracks', 'Star Laboratory', 'Drill Ground', 'Stone quarry', 'Gold Vault', 'Barrel Workshop', 'Wine Fountain', 
           'Apiary', 'Moat', 'Frost Witch', 'Pet House', 'Hero Totem', 'Soccer', 'Hall Legends', 'Eagle Artillery', 'Giga Tesla', 'Olive grove', 'Cannon', 'Hero Trap', 'Brewery', 'Loot Warehouse', 
           'Castle Gate', 'Wall', 'Sawmill', 'Siege workshop', 'Centaur Chieftain', 'Market Stall', 'Ruby Mine', 'Iron Roland', 'Elixir Storage', 'Laboratories ', 'Nomad Totem', 'Wizard Tower', 'Air Sweeper',
           'Giga Inferno (TH14)', 'Castle wall', 'Fire station', 'Jousting List', 'Bomb Tower', 'Training Center', 'Guild Hall', 'Gem Mine', 'Battle Machine Altar', 'Workshop', "Builder's Hut", 'Archer Queen Altar',
           'Watchtower', 'Mortar', 'Outhouse', 'Sundial', 'Coffin', 'Monuments', 'Laboratory', 'Arena', 'Magic Tower', 'Stonemason', 'Inferno Tower', 'Ninja', 'Willow Experience', 'Hidden Tesla', 'Thunder God',
           'Relicus', 'Storehouse', 'Military District', 'O.T.T.O Hut', 'Royal Towers', 'Cage', 'Bakery', 'Encampment', 'Air Defense', 'Weapons Rack', 'Gold Mine', 'Tower', 'Small Well', 'Hideout', 'Mana Vault',
           'Scattershot', 'Inner District', 'Dovecote', 'Relic Greenhouse', 'Bomb Trap', 'Research Tower', 'Pet_Plaza', 'Chimney', 'Carriage', 'Letters', 'Dry storage', 'Dark Elixir Storage', 'Walls', 'Numbers', 
           'Dark Elixir Drill', 'Rockin', 'Gold Knight', 'Marketplace', 'Town Hall', 'Terracotta Soldiers', 'Military Academy', 'Iron mine', 'Dragon Well', 'Hanging Cage', 'Gallows', 'Flagpole', 'Supplies',
           'Gold Storage', 'Relic Hall', 'Trading Metropolises', 'Ornamental Tree', 'Elixir Collector', 'Traps', 'Barracks', 'Witch Well', 'Guardhouse', 'Garrison', 'Military hospital', 'Warehouse', 'Spell Factory',
           'Hero Statue', 'Builder Hall', 'Theatre', 'Royal Champion Altar', 'Grand Warden Altar', 'Nymph Well', 'Trade District', 'Woodcutter', 'Market Barrows', 'Park', 'Hero Base', 'Giga Inferno (TH13)', 
           'Defense workshop', 'Signpost', 'Town house', 'Castle Garden', 'Farmhouse', 'Estate', "King's Tree", 'Archer Tower', 'Army Camp', 'Festival Square', 'Christmas Tree', 'Pillory', 'Mana Mill', 
           'Builder Barracks', 'Dwelling', 'Vlad Dracula'},
  "Resources_Rewards_Currency":{'Viewer Points', 'Shards', 'Odyssey Points', 'Fame', 'Points currencies', 'Coins', 'Badges', 'Time Skips', 'Silver coins ', 'Gold', 'Dragon Cores', 'Lee Youjin', 'Hongmoon Coin',
                            'Periodic Gold', 'Summoners experience', 'Rubies', 'Crystals', 'Buffs', 'Gems', 'Money', 'Acquiring gold', 'Food', 'Experience_XP', 'Celestial Peaches', 'Honor Badges', 'Starting gold',
                            'Naryu Silver', 'Achievement Points', 'Elixir', 'Copper coins ', 'Naryu Coin', 'Battle Points ', 'Mana', 'Gold coins ', 'Fire', 'Experience', 'Naryu Gold', 'Eosin', 'Dark Elixir',
                            'Champion experience', 'Favor', 'Gem'},
  "Items":{'Greater Belt Frenzy', 'Chempunk Chainsword', 'Cursed Blade', 'Restored Artifact', 'Kaya', 'Mask Madness', 'Arcane Blink', 'Hidden Dagger', 'Crusher', "Devourer's Gauntlet", 'Negatron Cloak', 'Lights', 
       'Scorching Blink Rune', 'Emblem Trembling Terror', 'Boots Speed ', "Jotunn's Wrath", 'Hailblade', 'Stopwatch', 'Tango', 'Conduit Gem', 'Transponder', 'Witchblade', 'Metalwork M', 'Perseverance', 'Surrogate station equipment', 
       'Talisman Energy', 'Hullbreaker', 'Toxic Blade', 'Seer Stone', 'Pridwen', 'Shadowflame', 'Dragon Lance ', 'Manikin Scepter', 'Book Dead', 'Envenomed Deathbringer', 'Breastplate Vigilance', 'Gem Fate',
       'Galeforce', 'Bank', 'Spirit Visage', 'Mystic Staff', "Jotunn's Ferocity", 'Smoke Deceit ', "Anathema's Chains", 'Faerie Charm', 'Bracer Radiance', 'Greater Horrific Emblem', 'Cull', 'Grove Bow', 
       'Large Fortune Potion', 'Flicker', 'Amulet Stronghold', 'Spirit Vessel', 'Black Spear', 'Faerie Fire ', 'Keen Optic', 'Book Souls', 'Compassion', 'Greater Shield Thorns', "Targon's Buckler", 'Ultimate Orb',
       'Sacrificial Shroud', 'Greater Aegis Amulet', 'Mekansm', "Giant's Belt", 'Lively Acorn', 'Cosmic Drive', 'Greater Purification Beads', 'Charged Bow', 'Sundering Axe', 'Stygian Desolator', 'Phantom Shell', 
       'Caduceus Shield', 'Horrific Emblem', 'Fiendish Codex', 'Ancient Blade', 'Bracer Illumination', "Spellthief's Edge", 'Hyperstone', 'Demon Edge', 'Glacial Buckler', 'Hearthbound Axe', 'Corrupted Blink Rune',
       'Voodoo Mask', 'Hastened Ring', 'Cloak', "Rabadon's Deathcap", 'Titan Sliver', 'Silverbranch Bow', 'Ward skins', 'Crown', 'Turbo Chemtank', 'Avatars', 'Chalice Mana', 'Iron Branch', 'Aegis of the Legion',
       'Leeching Leer', 'Robe Magi', 'Breastplate Determination', 'Wraith Band', "Winter's Approach", 'Eaglesong', 'Aegis Judgement', 'Echo Sabre', 'Hastened Wings', 'Sigil Old Guard', 'Wind Demon', 'Mystical Mail',
       'Bloodthirster', "Aghanim's Blessing", 'Sands Time', 'Spear Magus', 'Phage', 'Tainted Amulet', 'Sapphire Crystal', 'Obsidian Shard', 'Rageknife', 'Atmospheric brakes (includes air brakes and retro rocket brakes)',
       'Dominance', 'Doors', 'Umbral Glaive', 'Ninja Gear', 'Dynasty Plate Helm', 'Evenshroud', 'Mantle Intelligence', 'War Flag', 'Winged Blade', 'Hextech Rocketbelt', 'Seer Jungle', 'Boots Bearing ', 'Chaotic Beads', 
       'Phase Boots', 'Iron Mail', 'Short Sword', "Adventurer's Blade", 'Ring Aquila', 'Octarine Core', 'Paladin Sword', "Guinsoo's Rageblade", 'Spell Prism', 'Overwhelming Blink', "Tumbler's Toy", 'Relic Shield', 
       'Druid Stone', "Shogun's Kusari", 'Manamune', 'Aether Lens', "Caulfield's Warhammer", 'Ornate Arrow', 'Rod Healing', 'Bramble Vest', 'Sovereignty', 'Executioner', 'Magic Acorn', "Doran's Ring", 'Lost Chapter',
       'Fortified Scepter', "Lono's Mask", 'Blighted Ankh', 'Cursed Gauntlet', 'Fountain skins', 'Vampiric Scepter', 'Ward Stone', 'Decorative elements', 'Gilded Arrow', "Brigand's Blade", 'Blast Rig', 'God skins',
       'Mail Renewal', 'Yasha ,Kaya ', 'Black Mist Scythe', 'Contagion', 'Boots ravel', 'Support tech (landing gear and gyros)', 'Ogre Axe', 'Relic Dagger', 'Light Blade', 'In-game books', 'Tiamat', 
       'Town Portal Scroll ', 'Talon Trinket', 'Edge of Night', 'Sledge', 'Quest items', 'Fimbulwinter', 'Dagon', 'Runeforged Hammer', 'Null-Magic Mantle', 'Kraken Slayer', 'Gem Focus', 'Witchbane', "Knight's Shield", 
       'Steel Shoulderguards', 'Mind Breaker', 'Void Staff', 'Vambrace', "Death's Temper", "Zeke's Convergence", 'Radars', 'Multi Potion', 'Soul Gem', 'Armored Cloak', 'Spider Legs', 'Wrath Lich King', 'Warlords Draenor',
       'Pirate Hat', 'Spirit Robe', "Epicurean's Award", 'Shard of True Ice', 'Pestilence', 'Chalice Oracle', 'Possessed Mask', 'Loading frames', "Bumba's Dagger", 'Harrowing Crescent', "Sorcerer's Staff", 
       'Demonic Embrace', 'Thornmail', 'Tainted Breastplate', 'Chain Vest', "Baron's Brew", 'Forbidden Idol', 'Spiked Gauntlet', 'Tear of the Goddess', 'Witch Blade', 'Emberknife', 'Crystalline Bracer', 'Lich Bane', 
       'Aether Wisp', '8-Pointed Shuriken', 'Loading screen backgrounds', 'Ring Basilius', 'Soul   Reaver', 'Crown of the Shattered Queen', 'Maw of Malmortius', 'Rod Atos', 'Airfoil', 'Navori Quickblades',
       'Cloak Ascetic', 'Steel Mail', 'Heartseeker', 'Malicious Deathbringer', 'Heartward Amulet', 'Needlessly Large Rod', "Brawler's Beat Stick", 'Mining units', 'Music themes', 'Greater Cursed Ankh', 'Platemail', 
       'Zeal', 'Breastplate Valor', 'Telescope', "Death's Dance", 'Quicksilver Sash', 'Staff of Flowing Water', "Heaven's Halberd", 'Apex', 'Sentry Ward ', "Pythagorem's Piece", "Guardian's Orb", 'Phantom Dancer',
       'Chemtech Putrifier', 'Gem True Sight ', 'Nimble Rod Tahuti', 'Quickening Charm', 'Deep space asteroid tracker', 'Guardian Greaves ', 'Ethereal Staff', "Warmog's Armor", 'Arcane Boots', 'Emblem Increasing Peril', 
       'Power Treads (Agility)', 'Industry', 'Trusty Shovel', 'Axiom Arc', 'Temporal Beads', 'Power Treads (Strength)', 'Cataclysm', 'Jump stamps', 'Runic Shield', 'Dark Seal', "Guardian's Blade", 'Chalice Healing',
       "Bancroft's Talon", 'Silver Breastplate', "Prowler's Claw", 'Aegis Amulet', "Wit's End", 'Urn Shadows', 'Gleipnir', 'Sentry Ward', 'Aegis Acceleration', 'Territory scanner', "Archmage's Gem", "Pupil's Gift",
       'Mailboxes, forges, anvils permanent cooking fires', 'Frozen Heart', 'Divine Ruin', 'Ceremonial Robe', 'Hastened Katana', 'Sparklematic 5200', "Chronos' Pendant", 'Thousand Fold Blade', 'Medallion Courage',
       "Aghanim's Scepter", 'Arondight', 'Power Treads (Intelligence)', 'Alternate Timeline', 'Frostfang', "Hunter's Cowl", 'Enchanted Spear', 'Serrated Edge', 'Eye Jungle', 'Winged Moonplate', 'Magic Shell',
       'High tech transportation (warp drives and AGG)', 'Healing Tonic', 'Infinity Edge', "Randuin's Omen", 'Elixir Power', "Sage's Mask", 'Level-Up skins', "Warrior's Axe", "Rylai's Crystal Scepter", 'Warding Sigil', 
       'Vision Shard', 'Blighting Jewel', 'Observer Ward', 'Drowned Ankh', 'Heavy Hammer', "Sentinel's Embrace", 'Bracer Brilliance', 'Bracer', 'Maelstrom', 'Bound Gauntlet', "Dead Man's Plate", 'Fortune Potion',
       'Dagger', 'Spectral Armor', 'Duskblade of Draktharr', 'Watchful Wardstone', 'Oil', "Charon's Coin", 'Foundry Unit', 'Imperial Mandate', 'Soul Ring ', 'Thickbark Acorn', "Jade Emperor's Crown", 'Elevators',
       "Bumba's Hammer", 'Point Booster', 'Book Shadows', 'Cloak Concentration', 'Chairs', 'Blood-soaked Shroud', "Qin's Sais", 'Pig Pole', 'Shield generator', 'Manikin Mace', 'Calamitous Rod Tahuti', 'Bluestone Brooch',
       'Fallen Sky', 'Persistent Teleport', 'Hide Urchin', 'Blade of the Ruined King', 'Tainted Steel', 'Talisman Evasion', 'Pedestals', 'Locket of the Iron Solari', 'Displays', "Shifter's Shield", 'Helm Dominator',
       'Battle Azeroth', 'Trickster Cloak', "Doran's Shield", 'Cloak of Agility', 'Staff Wizardry ', 'HUD themes', 'Timeless Relic', 'Cursed Ankh', "Atalanta's Bow", 'Ravenous Hydra', 'Greater Heavenly Wings',
       'Mace', 'Long Sword', 'Last Whisper', 'Manikin Hidden Blade', "Sterak's Gage", "Doran's Blade", 'Emerald Talisman', 'Morbid Mask', 'Pickaxe', 'Cudgel', 'Magic Stick', 'Ex Machina', 'Bristlebush Acorn', 
       'Blink Rune', 'Corrupted Bluestone', 'Morellonomicon', 'Greater Bracer Radiance', 'Mirror Shield', "Gladiator's Shield", 'Dragon Scale', 'Sacred Relic', 'Magic Wand ', 'Containers', 'Deathbringer', 
       'Golden Blade', 'Glowing Emerald', 'Sunfire Aegis', 'Titanic Hydra', "Executioner's Calling", "Guardian's Hammer", "Odysseus' Bow", 'Midgardian Mail', 'Ruby Crystal', 'Kindlegem', "Sentinel's Boon",
       'Ring Health', 'Penta-Edged Sword', 'Telkhines Ring', 'Blasting Wand', 'Legion', 'Mjollnir', 'Blackthorn Hammer', 'Spellbook', 'Drum Endurance', "Mikael's Blessing", 'Essence Reaver', 'Shadowsteel Shuriken', 
       'Verdant Barrier', 'Bottle', 'Mantle Discord', 'Thorns Sapping Strength', 'Uncommon Staff', "Warrior's Bane", 'Hide Nemean Lion', 'Enchanted Mango', 'Bullwhip', 'Ring Regen', "Eul's Scepter Divinity", 
       'Ichaival', 'Vampiric Shroud', 'Transcendence', "Luden's Tempest", "Warden's Mail", 'Diamond Arrow', 'Gem Isolation', 'Relic', 'Imperial Helmet', 'Frostfire Gauntlet', 'Gargoyle Stoneplate', 'Gauntlet Thebes',
       'B. F. Sword', 'Arcane Ring', "Hunter's Bow", "Hydra's Lament", 'Shield Thorns', 'Void Stone', 'Belt Berserker', 'Dust Appearance', 'Ghost Scepter', 'Stridebreaker', 'Heroic Teleport', 'Emotes',
       "Death's Embrace", 'Stone Fal', 'Silvermere Dawn', 'Greater Teleport Fragment', 'Soul Eater', 'Belt Frenzy', 'Rage', 'Helm Overlord', 'Healing Salve', 'Spiked Shield', 'Wind Lace', 'Cloak of the Avatar',
       'Ocean Heart', 'Elven Tunic', 'Infused Sigil', 'Entangling Wings', 'Protector Jungle', 'Stone Binding', 'Gauntlets Strength', 'Katana', 'Announcer packs', 'Guardian Angel', 'Mob', 'Stormcrafter', 'Nether Shawl',
       'Tiny Trinket', 'Ward', 'Silver Talisman', 'Stone Gaia', 'Short Bow', 'Buckler', 'Belt of Strength ', 'Charged Morningstar', 'Shuriken', 'Warded Shield', 'Energy Booster', 'Enchanted Kusari', 'Cloak Flames',
       "Hero's Axe", 'Oblivion Orb', 'Breastplate', "Arcanist's Armor", 'Sange ,Yasha ', 'Pauldrons of Whiterock', 'Greater Magic Shell', 'Bandleglass Mirror', 'Bulwark of the Mountain', 'Scythe Vyse ', 
       'Tranquil Boots', 'Morningstar', 'Yasha', 'Enchanted Trinket', 'Sundering Siphon', "Philosopher's Stone", 'Spear Desolation', "Jotunn's Vigor", 'Repair unit', "Genji's Guard", "Serylda's Grudge", 
       'Serrated Dirk', 'Holy Locket', 'Black Cleaver', 'Spellbound Kusari', 'Mercurial Scimitar', 'Orchid Malevolence', "Leader's Cowl", 'Chipped Vest', 'Animosity', 'Rod Tahuti', "Archangel's Staff", 
       "Berserker's Shield", 'Mortal Reminder', 'Celestial Legion Helm', 'Ancile', 'Stone Cutting Sword', 'Frostbound Hammer', 'Hextech Alternator', 'Electronic elements', 'Slippers Agility ', "Bami's Cinder",
       "Magi's Cloak", 'Everfrost', "Zhonya's Hourglass", 'Bloodforge', 'Titles', 'Psychic Headband', 'Veil Discord', 'Clarity', 'Lotus Crown', 'Apprentice Staff', 'Force of Nature', 'Nettle Acorn', 'Null Talisman',
       "Guardian's Horn", 'Greater Sundering Spear', "Nashor's Tooth", 'Kaya ,Sange', 'Broom Handle', 'Cloak Meditation', 'Spartan Flag', 'Riftmaker', "Death's Toll", 'High tech (force fields and scaffolding projector)', 
       "Seeker's Armguard", "Runaan's Hurricane", "Giant's Ring", 'Cloth Armor', 'Abyssal Mask', 'Thistlethorn Acorn', 'Trinity Force', "Oni Hunter's Garb", "Emperor's Armor", 'Leveller', 'Teleport Fragment', 
       'Muramana', "Knight's Vow", 'Pendulum Ages', 'Heavy Mace', 'Moonstone Renewer', 'Wraith Pact', 'Horizon Focus', 'Leather Cowl', 'Tyrannical Plate Helm', 'Book Thoth', 'Spectral Sickle', 'Benevolence',
       'Fluffy Hat', "Aghanim's Shard", 'Recall skins', 'Purification Beads', "Shurelya's Battlesong", "Seraph's Embrace", "Ascetic's Cap", 'Tower Shield', 'Round Shield', 'Stormrazor', 'Worn Shoes',
       'Oblivion Staff ', 'Demonic Grip', 'Refresher Orb ', 'Emerald Ring', "Revenant's Brooch", 'Night Harvester', 'Asi', 'Sundering Spear', 'Core units', 'Talisman', 'Dumpling', 'Mask', 'Hongmoon Special Potion',
       'Orb Corrosion', 'Redemption', 'Wind Waker', 'Healing Potion', 'Amplifying Tome', 'Thorns Overgrowth', 'Rod Asclepius', 'Elixir Defense', 'Heavenly Wings', 'Ironspike Whip', 'Sundering Blast', 'Eye Skadi ',
       'Polynomicon', 'Doors levers open close ', 'Hand Gods', 'The Collector', '3D Printer', "Spectre's Cowl", 'Power Treads', "Liandry's Anguish", "Bumba's Spear", 'Belt Insatiable Hunger', "Fighter's Mask",
       'Various benches, chairs', 'Glimmer Cape', "Fairy's Trinket", 'Eclipse', "Typhon's Fang", 'Jade Mountain Helm', 'Rejuvenation Bead', 'Resurrection nodes', 'Noonquiver', 'Mage Slayer', 'Greater Cloak Meditation', 
       'Falcon Blade', "Baba's Brew", "Warlock's Staff", 'Enchanted Quiver', 'Kircheis Shard', 'Magic Focus', 'Diffusal Blade', "Banshee's Veil", 'Solar Crest', 'Pipe Insight', 'Force Boots', 'Ardent Censer', 
       'Evergreen Acorn', 'Vitality Booster', 'Sange', 'Force Staff', "Titan's Bane", 'Band Elvenskin', 'Control units', "Mejai's Soulstealer", 'Headdress', "Cleric's Cloak", 'Engines', "Lord Dominik's Regards",
       "Youmuu's Ghostblade", 'Blink Dagger', 'Honed Edge', 'Blade Alacrity ', 'Vigilant Wardstone', 'Amulet Silence', 'Cursed Orb', 'Worn Boots', 'Enchanted Ring', 'Shillelagh', "Rangda's Mask", 'Potion Power',
       'Rapid Firecannon', 'Fae Grenade', 'Greater Blink Rune', 'Bulwark Hope', 'Swift Blink', 'Doom Orb', 'Immortal Shieldbow', 'Satanic', 'Balanced Blade', 'Blueprints', 'War Banner', 'Emerald Mail', 'Mana Potion',
       "Serpent's Fang", 'Lost Artifact', 'Lucky Health Potion', 'Shield Regrowth', 'Tome Knowledge ', 'Staff Myrddin', 'Mists Pandaria', 'Quicksilver Amulet', 'Territory units', 'Circlet ', 'Bluestone Pendant',
       'Hand Midas', 'Fortifying Shell', 'Ring Hecate', 'Recurve Bow', 'Moon Shard ', 'Reaver', 'Divine Sunderer', "Sentinel's Gift", 'Goredrinker', 'Shadow Amulet', 'Spell Focus', "Vladmir's Offering", 
       "Hydra's Star", 'Enchanted Buckler', "Protector's Mask", 'Death marks', 'Hexdrinker', 'Fail-not', 'Void Shield', "Sage's Stone", 'Essence Ring', 'Sheen', 'Bag'},
"Weapons":{'Battle Fury', 'Monkey King Bar', 'Gauntlets', 'Abyssal Blade ', 'Radiance', 'Bloodthorn', 'Axes', 'Desolator', 'Staves', 'Crystalys', 'Daggers', 'Bangles', 'Bows', 'Orbs', 'Nullifier', 
         'Silver Edge', 'Shadow Blade', 'Greatswords', 'Skull Basher', 'Pistols', 'Meteor Hammer', 'Butterfly', 'Razors', 'Bracers', 'Daedalus', 'Lynblades', 'Swords', 'Divine Rapier', 'Armlet Mordiggian',
         'Weapon units', 'Ethereal Blade'},
 "Map":{
    "Howling Abyss","Summoner's Rift","Arena (Teamfight Tactics)","Battlefield","Bench","Skins","Base","Dark Star","Elemental","Fate (Fate Battle Pass)","Freljord","Galaxy","Gizmos & Gadgets ",
    "Lunar Revel","Neon Nights","Odyssey","Reckoning","Spirit Blossom","Kanmei","Festival","Akana","Dankest Dungeon","Desert Path","Golden Bakery Arena","High Noon Saloon","Journey's Beginning",
    "Black Hole","Celestial","Supernova","Infernal","Mountain","Cloud","Ocean","Factions","Lanes","River","Runes","Roshan","Jungle","Shops","Minimap","Vision","Terrain","Pathing","Towers","Barracks",
    "Outposts","Effigies","Ancient","Conquest","Assault","Arena","Joust","Slash","Custom","Viewer Store","Minions","Structures","Training"},
  "Materials_Elemenet":{"Al-Li","Aluminium","Brick","Calcium","Carbon","Carbon Fiber","Chromium","Cobalt","Concrete","Copper","Duralumin","Fluorine","Gold","Grade-5 Titanium Alloy","Inconel","Iron",
                          "Lithium","Mangalloy","Manganese","Maraging Steel","Marble","Nickel","Niobium","Plastic","Sc-Al","Scandium","Silicon","Silumin","Silver","Sodium","Stainless Steel","Steel",
                          "Sulfur","Titanium","Vanadium","Wood","Forest Soil","Moon Soil","Rock","Sand","Snow","Soil"},
  "Zone":{'Valley Four Winds ', 'Moonwater Plains', 'Suramar', 'Sholazar Basin', 'The Cinderlands', 'Stormsong Valley', 'Shadowmoon Valley ', 'Spires of Arak', 'Stormheim ', 'Nazjatar', 'Grizzly Hills ', 'Nazmir',
      'Isle Giants', 'Howling Fjord', 'Wintergrasp ', "Vol'dun", 'Zuldazar', 'Antoran Wastes ', 'Broken Isles', 'Viridian Coast', 'Nagrand', "Val'sharah", 'The Broken Shore', 'Zangar Sea', 'Argus', 'Dragonblight ',
      'Azjol-Nerub', 'Eastern Kingdoms', 'Helheim ', 'Drustvar', 'Icecrown', 'Shadowmoon Valley', "Hrothgar's Landing", 'Isle Thunder', 'Talador ', 'Coldarra', 'Veiled Stair', 'Kun-Lai Summit', 'Timeless Isle',
      'Pandaria', 'Ashran', 'Krokuun', 'Terokkar Forest', 'The Storm Peaks', 'Crystalsong Forest', 'Deepholm', 'Draenor', "Zul'Drak ", 'Tiragarde Sound ', 'Mechagon Island ', 'Silverfrost Mountains', 'Jade Forest ',
      'Azsuna ', 'Kul Tiras', 'Safe zone', 'Gorgrond', 'Northrend', 'Vale Eternal Blossoms ', 'Netherstorm', 'Eredath', 'Eye Azshara', 'Krasarang Wilds ', 'Highmountain ', 'Kalimdor', 'Townlong Steppes', 'Molten Front',
      'Frostfire Ridge', 'Tanaan Jungle', 'Outland', 'Helheim', 'Hellfire Peninsula', "Blade's Edge Mountains", 'Zangarmarsh', 'Zandalar', 'Borean Tundra', 'Dread Wastes'},
  "Planets_Biome":{"Moons","Asteroids","Helios","Alioth","Feli","Haven","Ion","Jago","Lacobus","Madis","Sanctuary","Sicari","Sinnen","Symeon","Talemai","Teoma","Thades","Forest","Plains","Mountains","Desert","Arctic",
                     "Vacuum","Veil"},
  "Dungeons":{"Lakeside Cache","Plague Hollow","Adder's Nest","The Darkglimpse","Sentinel Ruins","Naryu Temple","Pot Dog Shelter","The Ploghollows","Altar of Champions","Bogkon Hideout","Jukto's Repose","Lycandi Den",
                "Teetering Falls","Croak King's Court","Augerite Cavern","Pilfered Treasury","Skyhaven Stockade","Ebon Hall","Forgotten Tomb","Daggerbeak Rookery","The Pigsty","Hall of Ogong","Brightstone Ruins",
                "Skittering Tunnels","Tainted Lab","Talus Dungeon","Ogong's Folly","The Shrieking Caverns","Chuanka Frost Caverns","Ebondrake Hideout",'Blackram Narrows', 'Gloomdross Incursion', 'The Shattered Masts',
                'Ebondrake Citadel', 'Tomb of the Exiles', 'Blackram Supply Chain', 'Bloodshade Harbor', 'Naryu Labyrinth', "Mushin's Tower - 8th Floor", "Mushin's Tower - 15th Floor", 'Trial Arena', "Mushin's Tower - 20th Floor",
                'Tower of Infinity', 'Outlaw Island', 'Lair of the Frozen Fang', 'Awakened Necropolis', 'Avalanche Den', 'Sundered Nexus', "Sogun's Lament", 'Desolate Tomb', "Heaven's Mandate", 'Cold Storage', 'Hangar 0', 'Naryu Foundry',
                'Irontech Forge', 'Ebondrake Lair', 'The Shadowmoor', 'Naryu Sanctum', 'Starstone Mines', "Hollow's Heart", 'Drowning Deeps', 'Ransacked Treasury', 'Sandstorm Temple', 'Warped Citadel', 'Cathedra Cliffs', 'Circle of Sundering',
                'Spectral Shrine (Easy)', 'Stonescale Passage', 'Den of the Ancients', 'Spectral Shrine (Normal)', 'House of Idols', 'Spectral Shrine (Hard)', 'Dreamsong Theater', 'Brood Chamber', 'Halcyon Hills', 'Forest of Echoes','Silversteel Laboratory',
                'Midnight Skypetal Plains', 'The Steelbreaker', 'Twisted Serpent Stronghold', "Serpents' Den", 'Dawn of Khanda Vihar', 'Skybreak Spire (BT)', 'Fallen Aransu School', 'Snowjade Fortress', "Scion's Keep (SK)",
                'Temple of Eluvium (VT)', 'Hall of the Keeper', 'Hall of the Templar', 'Throne of Oblivion', 'Nightfall Sanctuary (TT)', 'Botany Center', 'Titan Chamber', 'Scarlet Conservatory (ET)',"Gruul's Lair",
                'Black Temple','Hellfire Ramparts', 'Blood Furnace', 'Shattered Halls', "Magtheridon's Lair",'Slave Pens', 'Underbog', 'Steamvault', 'Serpentshrine Cavern','Mana-Tombs', 'Auchenai Crypts', 'Sethekk Halls', 'Shadow Labyrinth',
                'Mechanar', 'Botanica', 'Arcatraz', 'Eye',"Seat Triumvirate","Antorus, the Burning Throne","Assault Violet Hold","Neltharion's Lair","Eye Azshara","Black Rook Hold","Maw Souls","Vault Wardens","Shaladrassil",
                "Darkheart Thicket","Emerald Nightmare","Halls Valor","Trial Valor","Arcway","Court Stars","Nighthold","Cathedral Eternal Night","Tomb Sargeras","Suramar City","Bloodmaul Slag Mines","Shadowmoon Burial Grounds",
                "Auchindoun","Skyreach","Iron Docks","Grimrail Depot","The Everbloom","Highmaul","Blackrock Foundry","Hellfire Citadel","Deadmines","Stockade","Sunken Temple","Zul'Gurub","Blackrock Depths","Lower Blackrock Spire",
                "Molten Core","Blackwing Lair","Blackrock Caverns","Blackwing Descent","Upper Blackrock Spire","Karazhan","Return Karazhan","Gnomeregan","Uldaman","Grim Batol","Bastion Twilight","Shadowfang Keep","Baradin Hold","Scholomance",
                "Scarlet Monastery","Scarlet Halls","Scarlet Monastery","Stratholme Main Gate","Stratholme Service Entrance","Zul'Aman","Magister's Terrace","Sunwell Plateau","Abyssal Maw","Throne of the Tides",
                "Firelands"," Blackfathom Deeps","Wailing Caverns","Maraudon","Onyxia's Lair","Ragefire Chasm","Razorfen Kraul","Dire Maul","Zul'Farrak","Lost City Tol'vir","Halls Origination","Razorfen Downs","Ruins Ahn'Qiraj",
                "Temple Ahn'Qiraj","Vortex Pinnacle","Throne Four Winds","Escape Durnholde Keep","Opening Dark Portal","Battle Mount Hyjal","Culling Stratholme","End Time","Well Eternity","Hour Twilight","Dragon Soul","Freehold",
                "Siege Boralus","Tol Dagor","Waycrest Manor","Shrine Storm","Crucible Storms","Operation: Mechagon","Temple Jade Serpent","Stormstout Brewery","Shado-Pan Monastery","Mogu'shan Palace","Gate Setting Sun","Siege Niuzao Temple",
                "Terrace Endless Spring","Mogu'shan Vaults","Heart Fear","Throne Thunder","Siege Orgrimmar"},
   "Monsters":{'Bulbari Forager', 'Blackram Guard', 'Blackram Seeker', 'Blackram Sentinel', 'Forest Wolf', 'Bright Lantern Imp', 'Bloody Jiangshi', 'Stalker Jiangshi', 'Graveyard Revenant', 'Gak Toshi',
                'Dusk Adder Scout', 'Dusk Adder Raider', 'Wild Bear', 'Dusk Adder Sniper', 'Dusk Adder Recruit', 'Dusk Adder Sentry', 'Dusk Adder Ambusher','Lantern Imp', 'Blackram Enforcer', 'Blackram Agent',
                'Blackram Taskmaster Limsu','Dusk Adder Captain Donbu', "Donbu's Underling", 'Dusk Adder Chopper', 'Dusk Adder Footpad', 'Dusk Adder Brawler', 'Dusk Adder Elite Su Hwan','Dusk Adder Guard', 'Dusk Adder Bandit',
                'Dusk Adder Captain Magomun', "Magomun's Underling", 'Dusk Adder Elite Kusim','Tomb Revenant', 'Infernal Jiangshi', 'Revenant Wong Minam', 'Dark Shaman Nekuro', "Nekuro's Awakened Guardian", "Nekuro's Summoned Phantom",
                'Blackram Scout', 'Blackram Convoy Soldier', 'Blackram Watcher', 'Blackram Thug', 'Blackram Marine', 'Blackram Trainee', 'Lieutenant Wungsam','Corrupted Fisher', 'Revenant Villager', 'Corrupted Beach Crab', 'Corrupted Hermit Crab',
                'Corrupted Pig', 'Bay Mite', 'Dusk Adder Cutpurse', 'Dusk Adder Duelist', 'Deathcap', 'Glow Sprite', 'Black Forest Spider', 'Deranged Kung Fu Master', 'Deranged Destroyer', 'Galusu', 'Ironmask Reaper',
                'Corrupted Cave Augerite', 'Corrupted Hulking Cave Augerite','Dusk Adder Thrasher', 'Dusk Adder Thief', 'Dusk Adder Observer', 'Dusk Adder Overseer Gu Du', 'Dusk Adder Overseer Ba Dun', 'Dusk Adder Overseer Ug Li',
                'Dreamroot Gnarlox', 'Dreamroot Gnarlhorn', 'Fiend', 'Dawnwood Lookout', 'Enraged Dreamroot Sprite','Dusk Adder Glider', 'Dusk Adder Goldkeeper', 'Dusk Adder Ebonywood Fetcher', 'Dusk Adder Overseer Furin',
                'Wild Bear', 'Gloomcap', 'Rotroot Bulbari', 'Hex Ploggle', 'Ploggosaur', 'Giganura','Thrasher', 'Cerulean Order Volunteer', 'Crimson Legion Volunteer', 'Furious Blade Master', 'Furious Destroyer', 'Furious Kung Fu Master',
                'Hansu', 'Cursed Training Dummy', 'Sansu', 'Wandering Training Dummy','Claypaw Top Dog Wu Fu', 'Dusk Adder Hunter', 'Dusk Adder Butcher', 'Dusk Adder Infiltrator', 'Hulking Totem', 'Dusk Adder Patrol', 'Sawtooth bulbari',
                'Stinging Nettlebug', 'Claypaw Robber', 'Claypaw Crook', 'Claypaw Pilferer', 'Rabid Claypaw Swindler', 'Vile Deathcap', 'Ravenous Vipercap', 'Sand Conch','Blackram Recruit', 'Blackram Cadet', 'Blackram Operative', 'Blackram Patrol',
                'Blackram Outrider', 'Blackram Trooper', 'Blackram Mercenary Captain', 'Blackram Mercenary', 'Blackram Mercenary Underling', 'Captain Gwon', 'Outcast Reaper', 'Stonebitter Brute','Ploggosaur', 'Hex Ploggle', 'Giganura',
                'Spikeshell Turtoise', 'Red Viper Looter', 'Warithbloom Lunatic', 'Southpyre Scout', 'Southpyre Missionary', 'Southpyre Cliff Searcher', 'Soft Shell Armordillo', 'Witherleaf Gnarlox', 'Runaway Convict', 'Red Viper Vanguard',
                'Red Viper Captain', 'Southpyre Pledge', 'Southpyre Acolyte', 'Southpyre Guard', 'Southpyre Watchdog', 'Southpyre Monk Pang Bok', 'Leaf Nettlebug', 'Southpyre Monk Pang Pek', 'Released Revenant', 'Thunderhead', 'Corrupted Han Soldier',
                'Clearspring Gnarlox', 'Purgewood Parasite','Golden Deva', 'Pinchy', 'Starving Wolf','Hakan', 'Bokgon Patrol', 'Bokgon Fighter', 'Terracotta Guard','Razorwing Ravine','Talus Army Watcher', 'Talus Army Guard', 'Talus Army Overseer',
                'Lycan The Mighty', 'Lycandi Archer', 'Bear','Pig', 'Greenleaf Gnarlox','Blackrams Spearman', 'Blackrams Archer', 'Blackrams Captain', 'Blackrams Patrol', 'Blackrams Swordman','Haunted bat', 'Skeleton Stratus Soldier', 'Rotting Stratus Undead',
                'Tainted Stratus Undead', 'Corrupted Guardian Tree', 'Haunted Jiangshi', 'Haunted Stalker Jiangshi', 'Razor Dokkaebi', 'Scissor Dokkaebi', 'Dokkaebi Crusher', 'Undead Snapjaw Shaman', 'Undead Snapjaw Warrior',
                'Profane JiangShi','Huren', 'Akakyu - Bear Guardian Huren', 'Akato - Tiger Guardian Huren', 'Talus Army Forward Base Commander', 'Forward Base Guard', 'Talus Army Engineer', 'Talus Army Mercenary Messenger', 'Talus Army Armsmaster',
                'Talus Army Forward Base Automation', 'Talus Army Forward Base Scout', 'T.R.I.N.I.T.Y.', 'Talus Army Patrol', 'Blackwyrm', 'Sapphire Terror', 'Vermillion Terror','Demonic Shaman', 'Skeleton Knight', 'Skeleton Warrior', 'Skeleton Shaman',
                'Reanimated Soldier', 'Bloodwing', 'Murking Lord', 'Ebonfiend Chopper', 'Twisted Ebonfiend', 'Ebonfiend Enforcer', 'Ebonfiend Striker', 'Hulking Fiend', 'Fiend', 'Blazefist', 'Demonic Knight', 'Demonic Warrior', 'Tainted Sentinel', 'Invader',
                'Corrupted Slayer', 'Slayer', 'Corrupted Ak Bul', 'Corrupted Cerulean Drill', 'Corrupted Crimson Drill', 'Corrupted Kung Fu Master', 'Corrupted Elite Destroyer', 'Corrupted Lancer', 'Corrupted Lancer (Talus)', 'Corrupted Archer', 'Corrupted Shieldbearer (Talus)',
                'Corrupted Blade Master', 'Corrupted Elite Force Master', 'Corrupted Resident', 'Yum Juh', 'Chang Juh', 'Corrupted Dondon', 'Grand Skorpio Demon', 'Tawny Skorpio Demon', 'Azure Skorpio Demon', 'Verdant Skorpio Demon', 'Alpha Wolf', 'Wolf', 'Forest Spider', 'Weaving Spider',
                'Lunar Grassquatch', 'Bulbari King'},
   "Arenas":{" Ring Trials - Nagrand","Arena Floor - Nagrand"," Circle Blood Arena - Blade's Edge Mountains"," Circle Blood - Blade's Edge Mountains","Ashamane's Fall - Val'sharah","Gurubashi Arena - Cape Stranglethorn ",
              "Ruins Lordaeron Arena - Tirisfal Glades","Northern Kalimdor","Ring Valor - Orgrimmar ","Tol'Viron Arena - Uldum","Dalaran Arena - Dalaran City"},                               
   "Professions_Activities":{
    'Riding', 'Acquired Taste', 'First Aid', 'Herbalism', 'Gatherer', 'Military', 'Spy', 'Fishing', 'Leader', 'Archaeology', 'Industrialist', 'Forgekeepers', 'Jewelcrafting', 
    'Tailoring', 'Engineering', 'Explorer', 'Skinning', 'Trader', 'Poisons', 'Runeforging', 'Pirate', 'Alchemy', 'Silver Cauldron', 'Builder', 'Inscription', 'Cooking', 'Enchanting', 'Soul Wardens',
    'Earthseers', 'Leatherworkingt', 'Lockpicking', 'Radiant Ring ', 'Mercenary', 'Blacksmithing', 'Mining'}
      


 }

# %% [markdown]
# # How mining mechanism get data from key elements categories of mesh dictionary

# %%
x1 = list(Characters["Professions_Activities"])

print(x1)
len(x1)
y1=[]
for i in range(0,len(x1)):
  y1.append('Mining')

print(y1)

x2 = list(Objects["Equipment_Tool"])
y2=[]
for i in range(0,len(x2)):
  y2.append('Mining')

x3 = list(World["Planets_Biome"]) 
y3=[]
for i in range(0,len(x3)):
  y3.append('Mining')

x4 = list(Objects["Materials_Elemenet"]) 
y4=[]
for i in range(0,len(x4)):
  y4.append('Mining')
  
x=x1+x2+x3+x4
y=y1+y2+y3+y4
# Out:
# ['Builder', 'Engineering', 'Leatherworkingt', 'First Aid', 'Tailoring', 'Leader', 'Riding', 'Spy', 'Leatherworking', 'Gatherer', 'Forgekeepers', 'Herbalism', 'Inscription', 'Lockpicking', 'Radiant Ring ', 'Industrialist', 'Earthseers', 'Fishing', 'Alchemy', 'Runeforging', 'Blacksmithing', 'Skinning', 'Explorer', 'Military', 'Pirate', 'Mining', 'Jewelcrafting', 'Archaeology', 'Trader', 'Silver Cauldron', 'Cooking', 'Mercenary', 'Acquired Taste', 'Soul Wardens', 'Poisons', 'Enchanting']
# ['Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining', 'Mining']

# %%
print("MINING")

import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

 

df = pd.DataFrame({ 'from':x, 'to':y})
 

G=nx.from_pandas_edgelist(df, 'from', 'to')
 

nx.draw(G, with_labels=True)
plt.show()




df = pd.DataFrame({ 'from':x, 'to':y})
 
G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() )
 
nx.draw(G, with_labels=True, node_size=1500, alpha=0.3, arrows=True)
plt.title("Directed")
plt.show()
# Out:
# MINING

# %% [markdown]
# # How Building mechanism get data from key elements categories of mesh dictionary

# %%
b1 = list(Characters["Professions_Activities"])


len(b1)
z1=[]
for i in range(0,len(b1)):
  z1.append('Building')


b2 = list(Objects["Equipment_Tool"])
z2=[]
for i in range(0,len(b2)):
  z2.append('Building')

b3 = list(World["Planets_Biome"]) 
z3=[]
for i in range(0,len(b3)):
  z3.append('Building')

b4 = list(Currencies_Economy["Resources_Rewards_currency"]) 
z4=[]
for i in range(0,len(b4)):
  z4.append('Building')

b=b1+b2+b3+b4
z=z1+z2+z3+z4

print("BUILDING")

import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

 

df = pd.DataFrame({ 'from':x, 'to':y})
 

G=nx.from_pandas_edgelist(df, 'from', 'to')
 

nx.draw(G, with_labels=True, node_color='red')
plt.show()




df = pd.DataFrame({ 'from':b, 'to':z})
 
G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() )
 
nx.draw(G, with_labels=True, node_size=1500, alpha=0.3, arrows=True , node_color='red')
plt.title("Directed")
plt.show()
# Out:
# BUILDING

# %% [markdown]
# # How Move mechanism get data from key elements categories of mesh dictionary

# %%
c1 = list(Characters["Classes"])


len(c1)
t1=[]
for i in range(0,len(c1)):
  t1.append('Move')


c2 = list(Objects["Equipment_Tool"])
t2=[]
for i in range(0,len(c2)):
  t2.append('Move')



c=c1+c2
t=t1+t2

print("MOVE")

import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

 

df = pd.DataFrame({ 'from':c, 'to':t})
 

G=nx.from_pandas_edgelist(df, 'from', 'to')
 

nx.draw(G, with_labels=True, node_color='pink')
plt.show()




df = pd.DataFrame({ 'from':b, 'to':z})
 
G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() )
 
nx.draw(G, with_labels=True, node_size=1500, alpha=0.9, arrows=True , node_color='pink')
plt.title("Directed")
plt.show()
# Out:
# MOVE

# %% [markdown]
# # How Create_a_Clan mechanism get data from key elements categories of mesh dictionary

# %%
q1 = list(Characters["Classes"])


len(q1)
v1=[]
for i in range(0,len(q1)):
  v1.append('Create_a_Clan')


q2 = list(Characters["Faction"])
v2=[]
for i in range(0,len(q2)):
  v2.append('Create_a_Clan')



q=q1+q2
v=v1+v2

print("Create_a_Clan")

import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

 

df = pd.DataFrame({ 'from':q, 'to':v})
 

G=nx.from_pandas_edgelist(df, 'from', 'to')
 

nx.draw(G, with_labels=True, node_color='yellow')
plt.show()




df = pd.DataFrame({ 'from':b, 'to':z})
 
G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() )
 
nx.draw(G, with_labels=True, node_size=1500, alpha=0.9, arrows=True , node_color='yellow')
plt.title("Directed")
plt.show()
# Out:
# Create_a_Clan

# %% [markdown]
# #How the connection of the mechanisms is represented in a graph.

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({ 'from':['Mining', 'Crafting2', 'Manufacturing','Attacking','Defending','Trade_Mechanism','Manufacturing','Killing_Damage'], 'to':['Crafting2', 'Building','Building','Killing_Damage','Killing_Damage','Rewards_Resources_Acquisition','Rewards_Resources_Acquisition','Rewards_Resources_Acquisition']})
 
# Build your graph. Note that we use the DiGraph function to create the graph!
Grafimataki=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() )
 
# Make the graph
nx.draw(Grafimataki, with_labels=True, node_size=1500, alpha=0.8, arrows=True , node_color= 'red', font_weight='bold')
plt.title("Directed")

for i in X.edges :
  for j in i :
    if j=='Mining':
      x.append('Mining')
      y.append(i[1])    
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() )
    if i[0]=='Building' :
      print(i[1])
      x.append(i[1])
      y.append('Building')
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() )
    if i[1]=='Building' :
      print(i[0])
      x.append(i[0])
      y.append('Building')
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() ) 
    if i[0]=='Manufacturing' :
      print(i[1])
      x.append('Manufacturing')
      y.append(i[1])
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() )
    if i[1]=='Manufacturing' :
      x.append('Manufacturing')
      y.append(i[0])
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() )
                 
nx.draw(Grafimataki, with_labels=True, node_size=1500, alpha=0.8, arrows=True , node_color= 'red', font_weight='bold')
plt.title("Directed")
# Out:
# Crafting2
# Crafting2
# Manufacturing
# Building
# Manufacturing
# Building
# Rewards_Resources_Acquisition
# Rewards_Resources_Acquisition
# Text(0.5, 1.0, 'Directed')

# %% [markdown]
# #The network above is read and then the connection is made after receiving data from the mesh

# %%
import networkx as nx
X = nx.Graph()
X.add_edges_from(Grafimataki.edges)
for i in X.edges :
  for j in i :
    if j=='Mining':
      x.append('Mining')
      y.append(i[1])    
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to')
      nx.draw(X, with_labels=True)
    if i[0]=='Building' :
      print(i[1])
      x.append(i[1])
      y.append('Building')
      x=x+b
      y=y+z
      print(x)
      print(y)
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to')
    if i[1]=='Building' :
      print(i[0])
      x.append(i[0])
      y.append('Building')
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to') 
    if i[0]=='Manufacturing' :
      x.append('Manufacturing')
      y.append(i[1])
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to')
    if i[1]=='Manufacturing' :
      x.append('Manufacturing')
      y.append(i[0])
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to')
    if i[0]=='Rewards_Resources_Acquisition' :
      x.append(i[1])
      y.append('Rewards_Resources_Acquisition')
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to')
    if i[1]=='Rewards_Resources_Acquisition' :
      x.append(i[0])
      y.append('Rewards_Resources_Acquisition')
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to')
    if i[0]=='Killing_Damage' :
      print(i[0])
      x.append(i[1])
      y.append('Killing_Damage')
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to')
    if i[1]=='Killing_Damage' :
      x.append(i[0])
      y.append('Killing_Damage')
      df = pd.DataFrame({ 'from':x, 'to':y})
      X=nx.from_pandas_edgelist(df, 'from', 'to')      
               
plt.show()
# Out:
# Crafting2
# Crafting2
# Manufacturing
# ...

# %% [markdown]
# **the same but with directed graph**

# %%
import networkx as nx
X = nx.Graph()
X.add_edges_from(Grafimataki.edges)
for i in X.edges :
  for j in i :
    if j=='Mining':
      x.append('Mining')
      y.append(i[1])    
    if i[0]=='Building' :
      x.append(i[1])
      y.append('Building')
    if i[1]=='Building' :
      x.append(i[0])
      y.append('Building') 
    if i[0]=='Manufacturing' :
      x.append('Manufacturing')
      y.append(i[1])
    if i[1]=='Manufacturing' :
      x.append('Manufacturing')
      y.append(i[0])
    if i[0]=='Rewards_Resources_Acquisition' :
      x.append(i[1])
      y.append('Rewards_Resources_Acquisition')
    if i[1]=='Rewards_Resources_Acquisition' :
      x.append(i[0])
      y.append('Rewards_Resources_Acquisition')
    if i[0]=='Killing_Damage' :
      print(i[0])
      x.append(i[1])
      y.append('Killing_Damage')
    if i[1]=='Killing_Damage' :
      x.append(i[0])
      y.append('Killing_Damage')      

df = pd.DataFrame({ 'from':x, 'to':y})
X=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() )               
nx.draw(X, with_labels=True, node_size=500, alpha=0.9, arrows=True, node_color= 'red')
plt.title("Directed")
plt.show()
# Out:
# Killing_Damage
# Killing_Damage
